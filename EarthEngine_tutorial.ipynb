# %% [markdown]
# From: https://github.com/earthlab/tutorials/blob/master/documentation/intro-google-earth-engine-python-api.md

# %%
import ee

# %%
ee.Initialize()

# %%
image = ee.Image('srtm90_v4')

# %%
image.getInfo()
# Out:
# {u'bands': [{u'crs': u'EPSG:4326',
#    u'crs_transform': [0.000833333333333,
#     0.0,
#     -180.0,
#     0.0,
#     -0.000833333333333,
#     60.0],
#    u'data_type': {u'max': 32767,
#     u'min': -32768,
#     u'precision': u'int',
#     u'type': u'PixelType'},
#    u'dimensions': [432000, 144000],
#    u'id': u'elevation'}],
#  u'id': u'srtm90_v4',
#  u'properties': {u'system:asset_size': 18827626666L,
#   u'system:time_end': 951177600000L,
#   u'system:time_start': 950227200000L},
#  u'type': u'Image',
#  u'version': 1494271934303000L}

# %%
from IPython.display import Image,display

# %%
url = image.getThumbUrl({'min':0,'max':3000})

# %%
img = Image(url+'.png')

# %%
img

# %%
Image('./test_thumb.png')
